# %% [markdown]
# # 🎙️ **AI Voice Box - Turbo Setup**
# यह नोटबुक आपके हगिंग फेस मॉडल को लोड करने के लिए तैयार है।

# %%
# @title 🚀 सेटअप
# !git clone https://github.com/shriramnag/Aivoicebox.git
# %cd Aivoicebox
# !pip install -r requirements.txt
print('✅ सेटअप पूरा हुआ!')

# %%
# @title 🎙️ ऐप शुरू करें
# !python app.py
