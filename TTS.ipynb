# %% [markdown]
# # 🎙️ **AI Voice Box - Ultimate Turbo Edition**
# यह नोटबुक आपके GitHub प्रोजेक्ट से जुड़ी है। इसमें हगिंग फेस मॉडल और टर्बो हाई स्पीड सेटअप शामिल है।

# %%
# @title 🚀 1. प्रोजेक्ट सेटअप (GitHub Clone)
import os
# %cd /content
# !git clone https://github.com/shriramnag/Aivoicebox.git
# %cd Aivoicebox

print("📥 लाइब्रेरीज़ इंस्टॉल हो रही हैं...")
# !pip install -r requirements.txt
# !apt-get install -y ffmpeg
print("✅ सेटअप पूरा हुआ!")

# %%
# @title 📥 2. हगिंग फेस मॉडल लोड करें
import os
os.makedirs("models", exist_ok=True)

PTH_URL = "https://huggingface.co/Shriramnag/%E0%A4%AE%E0%A4%BE%E0%A4%80%E0%A4%88-%E0%A4%B6%E0%A5%8D%E0%A4%B0%E0%A5%80%E0%A4%B0%E0%A4%BE%E0%A4%AE-%E0%A4%B5%E0%A5%89%E0%A4%87%E0%A4%B8/resolve/main/Shriramoriginalvoice.pth"
INDEX_URL = "https://huggingface.co/Shriramnag/%E0%A4%AE%E0%A4%BE%E0%A4%80%E0%A4%88-%E0%A4%B6%E0%A5%8D%E0%A4%B0%E0%A5%80%E0%A4%B0%E0%A4%BE%E0%A4%AE-%E0%A4%B5%E0%A5%89%E0%A4%87%E0%A4%B8/resolve/main/added_IVF579_Flat_nprobe_Shriramoriginalvoice_v2.index"

print("⚡ श्रीराम वॉयस मॉडल डाउनलोड हो रहा है...")
# !wget -q --show-progress {PTH_URL} -O models/shriram.pth
# !wget -q --show-progress {INDEX_URL} -O models/shriram.index
print("✅ मॉडल तैयार है!")

# %%
# @title 🎙️ 3. वॉयस क्लोनिंग इंटरफ़ेस शुरू करें
# !python app.py
