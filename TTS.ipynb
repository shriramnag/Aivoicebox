# %%
# @title 🚀 1. एंटी-स्लीप और टर्बो सेटअप
import os
from IPython.display import HTML
display(HTML('<script>setInterval(()=>{document.querySelector("colab-toolbar-button#connect").click()},60000)</script>'))

# %cd /content
# !rm -rf Aivoicebox
# !git clone https://github.com/shriramnag/Aivoicebox.git
# %cd Aivoicebox

print("⏳ टर्बो इंस्टॉलेशन जारी है...")
# !pip install --upgrade --no-cache-dir coqui-tts gradio==4.44.1 huggingface_hub pydub
# !apt-get install -y ffmpeg

print("✅ सेटअप पूरा हुआ!")

# %%
# @title 🎙️ 2. ऐप शुरू करें
# !python app.py
