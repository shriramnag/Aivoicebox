# %% [markdown]
# # 🎙️ श्रीराम वाणी - प्रोफेशनल AI इंजन (10K Support)
# यह नोटबुक आपके **XTTS-v2** मॉडल को 'टर्बो हाई स्पीड' पर चलाने के लिए डिज़ाइन की गई है। [cite: 2026-01-06]

# %%
# @title 🚀 टर्बो सेटअप शुरू करें
import os

# 1. सिस्टम की सफाई और नया क्लोन
# %cd /content
if os.path.exists('/content/Aivoicebox'):
    # !rm -rf Aivoicebox
# !git clone https://github.com/shriramnag/Aivoicebox.git
# %cd Aivoicebox

# 2. लाइब्रेरी इंस्टॉलेशन (No-Error Mode) [cite: 2026-01-06]
print("⏳ टर्बो लाइब्रेरीज़ लोड हो रही हैं...")
# !pip install --no-cache-dir -r requirements.txt
# !apt-get install -y ffmpeg

print("✅ सेटअप पूरा हुआ! अब नीचे वाला सेल चलाएँ।")

# %%
# @title 🎙️ ऐप लॉन्च करें
# यह आपके app.py और सभी 6 सपोर्टिंग फाइलों को एक्टिवेट कर देगा [cite: 2026-01-06]
# !python app.py
