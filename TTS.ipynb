# %% [markdown]
# # 🎙️ श्रीराम वाणी - प्रोफेशनल AI इंजन v2 (Turbo Enabled)
# **विशेषताएँ:**
# * ✅ **Anti-Sleep:** कोलाब को डिस्कनेक्ट होने से रोकेगा।
# * ✅ **Stutter Fix:** आवाज़ का हकलाना बंद करेगा।
# * ✅ **Turbo Speed:** GPU का पूरा उपयोग करेगा। [cite: 2026-01-06]

# %%
# @title 🚀 1. एंटी-डिस्कनेक्ट स्क्रिप्ट (एक्टिवेट करें)
import IPython
from IPython.display import HTML

# यह स्क्रिप्ट हर 60 सेकंड में कोलाब को 'जीवित' रखेगी
js_code = '''
function ClickConnect(){
  console.log("Keeping Colab Awake...");
  document.querySelector("colab-toolbar-button#connect").click() 
}
setInterval(ClickConnect, 60000)
'''
display(HTML('<script>'+js_code+'</script>'))
print("✅ एंटी-स्लीप एक्टिवेट हो गया है! अब आप निश्चिंत होकर जनरेट करें।")

# %%
# @title 🚀 2. सेटअप और टर्बो इंस्टॉलेशन
import os

# पुराने कचरे को साफ करना
# %cd /content
# !rm -rf Aivoicebox

# GitHub से फ्रेश कोड डाउनलोड करना
print("📥 GitHub से रिपोजिटरी क्लोन की जा रही है...")
# !git clone https://github.com/shriramnag/Aivoicebox.git
# %cd Aivoicebox

print("⏳ लाइब्रेरी इंस्टॉल हो रही हैं (इसमें 2-3 मिनट लग सकते हैं)...")
# वर्जन लॉक ताकि 'HfFolder' और हकलाने वाला एरर न आए [cite: 2026-01-06]
# !pip install --upgrade --no-cache-dir huggingface_hub==0.23.2 gradio==4.44.1 coqui-tts pydub num2words
# !apt-get install -y ffmpeg

print("✅ सेटअप पूरा हुआ! नीचे वाला सेल चलाकर ऐप शुरू करें।")

# %%
# @title 🎙️ 3. श्रीराम वाणी इंजन लॉन्च करें
# पुरानी .wav फाइलों को साफ करना ताकि नया ऑडियो फ्रेश बने
# !rm -rf *.wav

print("🚀 इंजन शुरू हो रहा है...")
# !python app.py
