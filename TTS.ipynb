# %% [markdown]
# # 🎙️ श्रीराम वाणी - टर्बो इंजन (Anti-Sleep Mode Enabled)
# **निर्देश:** इस नोटबुक को चलाने के बाद ब्राउज़र टैब को बंद न करें। [cite: 2026-01-06]

# %%
# @title 🚀 1. एंटी-डिस्कनेक्ट स्क्रिप्ट (इसे चलाकर छोड़ दें)
import IPython
js_code = '''
function ClickConnect(){
  console.log("Working...");
  document.querySelector("colab-toolbar-button#connect").click() 
}
setInterval(ClickConnect, 60000)
'''
display(IPython.display.HTML('<script>'+js_code+'</script>'))
print("✅ एंटी-स्लीप एक्टिवेट हो गया है!")

# %%
# @title 🚀 2. सेटअप और लॉन्च
import os
# %cd /content
# !rm -rf Aivoicebox
# !git clone https://github.com/shriramnag/Aivoicebox.git
# %cd Aivoicebox

print("⏳ लाइब्रेरी इंस्टॉल हो रही हैं...")
# !pip install --upgrade --no-cache-dir coqui-tts gradio huggingface_hub pydub
# !apt-get install -y ffmpeg

print("✅ इंजन शुरू हो रहा है...")
# !python app.py
