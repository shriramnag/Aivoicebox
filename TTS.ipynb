# %% [markdown]
# # 🎙️ श्रीराम वाणी - प्रोफेशनल AI वॉइस क्लोनिंग (10K Support)
# यह नोटबुक आपके GitHub प्रोजेक्ट को सीधे कोलाब में चलाती है। [cite: 2026-01-06]

# %%
# @title 🚀 टर्बो सेटअप शुरू करें
import os

# 1. पुरानी फाइलों को साफ करना
# %cd /content
if os.path.exists('/content/Aivoicebox'):
    # !rm -rf Aivoicebox

# 2. GitHub से नया प्रोफेशनल वर्जन डाउनलोड करना
# !git clone https://github.com/shriramnag/Aivoicebox.git
# %cd Aivoicebox

# 3. सही लाइब्रेरी इंस्टॉल करना (HfFolder एरर फिक्स के साथ)
print("⏳ टर्बो इंस्टॉलेशन चालू है...")
# !pip install --no-cache-dir -r requirements.txt
# !apt-get install -y ffmpeg

print("✅ सेटअप पूरा हुआ! अब नीचे वाला सेल चलाएँ।")

# %%
# @title 🎙️ ऐप लॉन्च करें
# यह आपके app.py और बाकी सभी 6 फाइलों को एक्टिवेट कर देगा [cite: 2026-01-06]
# !python app.py
